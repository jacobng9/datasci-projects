# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import ElementClickInterceptedException, NoSuchElementException
import time
from bs4 import BeautifulSoup

# Setup Chrome options
chrome_options = Options()
chrome_options.add_argument("--start-maximized")

# Path to ChromeDriver
driver_path = "path/to/chromedriver"

# Start the driver
driver = webdriver.Chrome()

try:
    # Load the target website
    driver.get("https://secure-bonus-377122.uc.r.appspot.com/level4")

    player1_hash = "4b6c244d68296a6569"
    # Get the player buttons and store them
    buttons = driver.find_elements(By.CLASS_NAME, "player")

    # Variable to store Player 1 button
    player_1 = driver.find_element(By.CLASS_NAME, "4b6c244d68296a6569") 

        # Example: Extract the scheduledPlayerIndex from JavaScript
    scheduled_player_index = driver.execute_script("return scheduledPlayerIndex;")

    # Print the scheduledPlayerIndex
    print(f"Scheduled Player Index: {scheduled_player_index}")

    time.sleep(3.5)


    def get_scheduled_player():
        light_color = driver.find_element(By.ID, "light").get_attribute("style")
        if "red" in light_color:  # Assuming light turns red when nudging happens
            # Check which player is the scheduled one (nudged player)
            scheduled_player = None
            for button in buttons:
                player_index = button.get_attribute("data-player-index")
                if player_index != "0":  # Player 1 is not the scheduled player
                    scheduled_player = button
                    break
            return scheduled_player
        return None

    # Main loop to monitor the red light and find the scheduled player
    while True:
        scheduled_player = get_scheduled_player()
        if scheduled_player:
            print("Scheduled Player is: ", scheduled_player.text)
        time.sleep(1)  


except Exception as e:
    print(f"Error: {e}")

finally:
    time.sleep(2) 
    driver.quit()
# Out:
# Error: Message: invalid selector: An invalid or illegal selector was specified
#   (Session info: chrome=135.0.7049.42); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalid-selector-exception
# Stacktrace:
# 0   chromedriver                        0x00000001045b9f14 cxxbridge1$str$ptr + 2816404
# 1   chromedriver                        0x00000001045b21cc cxxbridge1$str$ptr + 2784332
# 2   chromedriver                        0x00000001040fa40c cxxbridge1$string$len + 93024
# 3   chromedriver                        0x0000000104100010 cxxbridge1$string$len + 116580
# 4   chromedriver                        0x000000010410234c cxxbridge1$string$len + 125600
# 5   chromedriver                        0x00000001041023f4 cxxbridge1$string$len + 125768
# 6   chromedriver                        0x0000000104140dac cxxbridge1$string$len + 382208
# 7   chromedriver                        0x00000001041822f4 cxxbridge1$string$len + 649800
# 8   chromedriver                        0x00000001041355bc cxxbridge1$string$len + 335120
# 9   chromedriver                        0x000000010457e53c cxxbridge1$str$ptr + 2572220
# 10  chromedriver                        0x0000000104581800 cxxbridge1$str$ptr + 2585216
# 11  chromedriver                        0x000000010455e518 cxxbridge1$str$ptr + 2441112
# 12  chromedriver                        0x0000000104582078 cxxbridge1$str$ptr + 2587384
# 13  chromedriver                        0x000000010454f6b0 cxxbridge1$str$ptr + 2380080
# 14  chromedriver                        0x00000001045a2550 cxxbridge1$str$ptr + 2719696
# 15  chromedriver                        0x00000001045a26dc cxxbridge1$str$ptr + 2720092
# 16  chromedriver                        0x00000001045b1e18 cxxbridge1$str$ptr + 2783384
# 17  libsystem_pthread.dylib             0x000000019b642f94 _pthread_start + 136
# 18  libsystem_pthread.dylib             0x000000019b63dd34 thread_start + 8
